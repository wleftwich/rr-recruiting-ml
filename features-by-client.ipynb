# %%
import pandas as pd

# %%
features_file = 'data/cig_features.parq'

# %%
df = pd.read_parquet(features_file)

# %%
len(df)
# Out:
# 5113

# %%
df.sample(5).T
# Out:
#                                                                        1755  \
# lead_id                                                             9270503
# form_data_id                                                         450416
# lead_match_client_id                                                   5575
# structured_campaign_name  Crete Carrier Corporation : National : PMC p5 ...
# company_nicename                                  Crete Carrier Corporation
# full_name                                                    Jacquelin Remy
# hired                                                                     0
# city                                                                Orlando
# state                                                                    FL
# zip                                                                   32811
# years_otr_exp                                                    3-6 months
# ...

# %%
df.groupby('lead_match_client_id').size().sort_values(ascending=False).head(20)
# Out:
# lead_match_client_id
# 11      966
# 5575    741
# 5709    569
# 5798    520
# 5861    318
# 5692    222
# 5815    196
# 5610    136
# 10      116
# 5559     88
# 5795     74
# 3        70
# 42       54
# 5893     52
# 88       48
# 5881     41
# 5693     40
# 5737     39
# 5817     37
# 5569     36
# dtype: int64
