# %% [markdown]
# # Careers in gear
# ## Predict hire / nohire from lead_details.csv
#
# ### MLP model with embedded category vectors

# %%
import logging
logging.basicConfig()
logger = logging.getLogger()
logger.setLevel('ERROR')

import shutil
import pathlib
import pickle
import itertools

import pandas as pd
import numpy as np
import joblib

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler, MinMaxScaler, FunctionTransformer

# from sklearn.model_selection import GridSearchCV
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    roc_curve,
    roc_auc_score,
    precision_recall_curve,
    precision_score,
    recall_score,
    average_precision_score
)
# from sklearn import linear_model

from tensorflow.keras import models, layers

# from feature_utils import CategoricalEncoder, DataFrameSelector

from pp_pipeline_utils import (
    splitx,
    DataFrameSelector,
    CategoricalEncoder
)

from metric_utils import (
    plot_precision_recall,
    plot_roc,
    plot_precision_vs_score,
    precision_at_score_percentile,
    precision_by_score_buckets,
    plot_precision_by_score_buckets,
    plot_bucket_counts
)

# from score2ppv import score2ppv, score2ppv_model

# %%
np.random.seed(42)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_palette(sns.color_palette("Set2", 10))

# %%
features_file = 'data/cig_features.parq'

# %%
features = pd.read_parquet(features_file)

# %%
features.sample(5).T
# Out:
#                                                                        4522  \
# lead_id                                                             9055365
# form_data_id                                                         438970
# lead_match_client_id                                                   5815
# structured_campaign_name  Martin Resource Management : Regional (Martin ...
# company_nicename                                 Martin Resource Management
# full_name                                                       Curtis Hale
# hired                                                                     0
# city                                                               Longview
# state                                                                    TX
# zip                                                                   75604
# years_otr_exp                                                   11-15 years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    1
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                1
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   0
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   1
# van                                                                       1
# reefer                                                                    0
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               1
# exp_yr_num                                                               13
# climate_region                                                            S
#
#                                                                        2499  \
# lead_id                                                             9337921
# form_data_id                                                         454948
# lead_match_client_id                                                   5709
# structured_campaign_name  Trans System Inc : System Transport Pacific No...
# company_nicename                                           System Transport
# full_name                                                      Danny Malone
# hired                                                                     0
# city                                                             Long Beach
# state                                                                    CA
# zip                                                                   90804
# years_otr_exp                                                  18-24 months
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                0
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   1
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                                2
# climate_region                                                            W
#
#                                                                       1413  \
# lead_id                                                            1660939
# form_data_id                                                        230119
# lead_match_client_id                                                    10
# structured_campaign_name  US Xpress : Dedicated : p5 : a13 : M_1140093 (R)
# company_nicename                                                 US Xpress
# full_name                                                    Louis Hubbard
# hired                                                                    1
# city                                                            Montgomery
# state                                                                   AL
# zip                                                                  36106
# years_otr_exp                                                   0-3 months
# lease_purchase                                                           0
# drivers_license_class_a                                                  1
# driver_type                                                        student
# hazmat                                                                   0
# tanker                                                                   0
# doublestriples                                                           0
# tickets                                                                  0
# job_alerts                                                               1
# sms_alerts_opt_in                                                        0
# came_from_suggested_job                                                  0
# run_single                                                               0
# run_team                                                                 0
# flatbed                                                                  0
# van                                                                      0
# reefer                                                                   0
# specialized                                                              0
# multi                                                                    0
# oversized                                                                0
# stepdeck                                                                 0
# heavy_haul                                                               0
# haul_tanker                                                              0
# exp_yr_num                                                            0.25
# climate_region                                                          SE
#
#                                                                        4357  \
# lead_id                                                            13010742
# form_data_id                                                        1134721
# lead_match_client_id                                                     11
# structured_campaign_name  K and B Transportation Inc. : otr (OTR 4) : PM...
# company_nicename                                         K&B Transportation
# full_name                                                      ROBERT TOBAR
# hired                                                                     1
# city                                                              Covington
# state                                                                    TN
# zip                                                                   38019
# years_otr_exp                                                  18-24 months
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                1
# sms_alerts_opt_in                                                         0
# came_from_suggested_job                                                   1
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    0
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                                2
# climate_region                                                            C
#
#                                                                        3830
# lead_id                                                            10484415
# form_data_id                                                         672895
# lead_match_client_id                                                   5817
# structured_campaign_name  Ozark : Company Driver : PMC p5 : a1 : M_11350...
# company_nicename                                     Ozark Motor Lines, Inc
# full_name                                                       Joel Bishop
# hired                                                                     1
# city                                                              Flat Rock
# state                                                                    NC
# zip                                                                   28731
# years_otr_exp                                                       5 years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                0
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   0
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   1
# van                                                                       1
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                                5
# climate_region                                                           SE

# %%
features.hired.sum()
# Out:
# 1558

# %%
features.hired.sum() / len(features)
# Out:
# 0.30471347545472327

# %%
def ordinal_keys(s):
    sset = set(s)
    sset.add('')
    return sorted(sset)

# %%
category_keys = [
    'driver_type',
    'climate_region'
]

for ck in category_keys:
    features[ck] = features[ck].fillna('')

category_values = {x: ordinal_keys(features[x].unique()) for x in category_keys}
category_lookup = {x:x for x in category_keys}

def get_cat_vals(cat):
    return category_values[category_lookup[cat]]

def make_cat_encoder(atts, encoding='onehot', handle_unknown='ignore'):
    return CategoricalEncoder(encoding=encoding,
                              categories=[get_cat_vals(x) for x in atts],
                              handle_unknown=handle_unknown)

# %%
numeric_atts = [
    'exp_yr_num',
    'tickets',
    # rest are boolean
    
    'lease_purchase',
    'drivers_license_class_a',
    'hazmat',
    'tanker',
    'doublestriples',
    'job_alerts',
    'sms_alerts_opt_in',
    'came_from_suggested_job',
    'run_single',
    'run_team',
    'flatbed',
    'van',
    'reefer',
    'multi',
    'oversized',
    'stepdeck',
    'heavy_haul',
    'haul_tanker',
]

category_atts = [
    'driver_type',
    'climate_region'
]

# %%
train_set, test_set = train_test_split(features.copy(), test_size=0.2)
len(train_set), len(test_set)
# Out:
# (4090, 1023)

# %%
splitx_ft = FunctionTransformer(splitx, validate=True, kw_args={'numlen': len(numeric_atts)})

# %%
num_pipeline = Pipeline([
    ('num_selector', DataFrameSelector(numeric_atts)),
    ('std_scaler', StandardScaler())
])

cat_pipeline = Pipeline([
    ('cat_selector', DataFrameSelector(category_atts)),
    ('ordinal_encoder', make_cat_encoder(category_atts, encoding='ordinal', handle_unknown='error'))
])

fu_pipeline = FeatureUnion([
    ('num_pipeline', num_pipeline),
    ('cat_pipeline', cat_pipeline)
])

pipeline = Pipeline([
    ('fu_pipeline', fu_pipeline),
    ('splitx_ft', splitx_ft)
])

# %%
# %%time
pipeline.fit(train_set)
# Out:
# CPU times: user 11.3 ms, sys: 0 ns, total: 11.3 ms
# Wall time: 10.7 ms
# Pipeline(memory=None,
#          steps=[('fu_pipeline',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('num_pipeline',
#                                                  Pipeline(memory=None,
#                                                           steps=[('num_selector',
#                                                                   DataFrameSelector(attribute_names=['exp_yr_num',
#                                                                                                      'tickets',
#                                                                                                      'lease_purchase',
#                                                                                                      'drivers_license_class_a',
#                                                                                                      'hazmat',
#                                                                                                      'tanker',
#                                                                                                      'doublestriples',
#                                                                                                      'job_alerts',
#                                                                                                      'sms_alerts_opt_in',
#                                                                                                      'came_from_suggested_job',
#                                                                                                      'run_sing...
#                                                                                      dtype=<class 'numpy.float64'>,
#                                                                                      encoding='ordinal',
#                                                                                      handle_unknown='error'))],
#                                                           verbose=False))],
#                               transformer_weights=None, verbose=False)),
#                 ('splitx_ft',
#                  FunctionTransformer(accept_sparse=False, check_inverse=True,
#                                      func=<function splitx at 0x7f3d326041e0>,
#                                      inv_kw_args=None, inverse_func=None,
#                                      kw_args={'numlen': 20},
#                                      pass_y='deprecated', validate=True))],
#          verbose=False)

# %%
X_train = pipeline.transform(train_set)
y_train = train_set.hired

# %%
X_test = pipeline.transform(test_set)
y_test = test_set.hired

# %%
inputs = []
base_layers = []
embedclasses = {}

numeric_count = len(numeric_atts)
inp = layers.Input(shape=(numeric_count,))
inputs.append(inp)
numeric_layer = layers.Dense(numeric_count, name='numeric_input')(inp)
base_layers.append(numeric_layer)

for catname in category_atts:
    m = len(get_cat_vals(catname))
    n = min((m + 1) // 2, 50)
    embedname = category_lookup[catname]
    if embedname in embedclasses:
        embedclass = embedclasses[embedname]
    else:
        embedclass = layers.Embedding(m, n, input_length=1, name=(embedname + '_embedding'))
        embedclasses[embedname] = embedclass
    inp = layers.Input(shape=(1,))
    inputs.append(inp)
    emb = embedclass(inp)
    emb_reshaped = layers.Reshape(target_shape=(n,))(emb)
    base_layers.append(emb_reshaped)

# %%
len(X_train)
# Out:
# 3

# %%
[x.shape for x in X_train]
# Out:
# [(4090, 20), (4090,), (4090,)]

# %%
x = layers.Concatenate()(base_layers)
x = layers.Dense(16, activation='relu')(x)
x = layers.Dropout(0.2)(x)
output = layers.Dense(1, activation='sigmoid')(x)

model = models.Model(inputs, output)
model.compile(optimizer='rmsprop', loss='binary_crossentropy')

# %%
# %%time
history = model.fit(X_train, y_train, batch_size=1024, epochs=40,
          class_weight=compute_class_weight('balanced', [0,1], y_train)
         )

# %%
y_score = model.predict(X_test)

# %%
roc_auc_score(y_test, y_score)
# Out:
# 0.8257374950412925

# %%
average_precision_score(y_test, y_score)
# Out:
# 0.7068694851518692

# %%
precision_at_score_percentile(y_test, y_score, 80)

# %%
precision_at_score_percentile(y_test, y_score, 90)
# Out:
# 0.8446601941747572

# %%
precision_at_score_percentile(y_test, y_score, 99)
# Out:
# 1.0

# %%
plot_roc(y_test, y_score)

# %%
plot_precision_recall(y_test, y_score)

# %%
plt.figure(figsize=(24,8))
plot_bucket_counts(y_test, y_score, 10)

# %%
len(test_set)
# Out:
# 1023

# %%
len(y_score)
# Out:
# 1023

# %%
y_score
# Out:
# array([[0.11944366],
#        [0.16914484],
#        [0.86933947],
#        ...,
#        [0.07916088],
#        [0.8039413 ],
#        [0.27172258]], dtype=float32)

# %%
test_set['score'] = y_score

# %%
test_set.sample(5).T
# Out:
#                                                                        1954  \
# lead_id                                                             9053010
# form_data_id                                                         438891
# lead_match_client_id                                                   5575
# structured_campaign_name  Crete Carrier Corporation : National : PMC p75...
# company_nicename                                  Crete Carrier Corporation
# full_name                                                Christopher Rawles
# hired                                                                     0
# city                                                            Franklinton
# state                                                                    LA
# zip                                                                   70438
# years_otr_exp                                                       2 years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                0
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   0
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   1
# van                                                                       1
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 1
# stepdeck                                                                  1
# heavy_haul                                                                1
# haul_tanker                                                               0
# exp_yr_num                                                                2
# climate_region                                                            S
# score                                                              0.304501
#
#                                                                        2193  \
# lead_id                                                             9348456
# form_data_id                                                         455772
# lead_match_client_id                                                      3
# structured_campaign_name  Marten Transport Ltd. : National-OTR : PMC p5 ...
# company_nicename                                           Marten Transport
# full_name                                                      Nancy Carter
# hired                                                                     1
# city                                                              Vancouver
# state                                                                    WA
# zip                                                                   98662
# years_otr_exp                                                   26-29 years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    1
# doublestriples                                                            1
# tickets                                                                   0
# job_alerts                                                                0
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   0
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       0
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                               27
# climate_region                                                           NW
# score                                                              0.288529
#
#                                                                        2621  \
# lead_id                                                             9230668
# form_data_id                                                         446492
# lead_match_client_id                                                   5926
# structured_campaign_name  Ozark Logistics LLC : Company Drivers : PMC p5...
# company_nicename                                        Ozark Logistics LLC
# full_name                                                    Gayland Fraser
# hired                                                                     0
# city                                                            Weatherford
# state                                                                    OK
# zip                                                                   73096
# years_otr_exp                                                       2 years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    1
# doublestriples                                                            1
# tickets                                                                   0
# job_alerts                                                                0
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   0
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    0
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               1
# exp_yr_num                                                                2
# climate_region                                                            S
# score                                                              0.222282
#
#                                                                        1188  \
# lead_id                                                             9831398
# form_data_id                                                         518550
# lead_match_client_id                                                   5709
# structured_campaign_name  Trans System Inc : System Transport Denver : P...
# company_nicename                                           System Transport
# full_name                                                     Joaquin Lopez
# hired                                                                     0
# city                                                                Wichita
# state                                                                    KS
# zip                                                                   67219
# years_otr_exp                                                    0-3 months
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                1
# sms_alerts_opt_in                                                         0
# came_from_suggested_job                                                   1
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    0
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                             0.25
# climate_region                                                            S
# score                                                              0.199275
#
#                                                                        1508
# lead_id                                                            11504907
# form_data_id                                                         915913
# lead_match_client_id                                                     11
# structured_campaign_name  K and B Transportation Inc. : otr (OTR 4) : PM...
# company_nicename                                         K&B Transportation
# full_name                                                Richardson Johnson
# hired                                                                     1
# city                                                                Houston
# state                                                                    TX
# zip                                                                   77026
# years_otr_exp                                                    6-9 months
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    1
# doublestriples                                                            1
# tickets                                                                   0
# job_alerts                                                                0
# sms_alerts_opt_in                                                         0
# came_from_suggested_job                                                   1
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               1
# exp_yr_num                                                             0.75
# climate_region                                                            S
# score                                                              0.130394

# %%
test_set.to_excel('data/cig_test_scored.xlsx', index=False)
