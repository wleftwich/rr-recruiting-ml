# %% [markdown]
# # Careers in gear
# ## Predict hire / nohire from lead_details.csv
#
# ### Keras logistic regression (no hidden layer)

# %%
import logging
logging.basicConfig()
logger = logging.getLogger()
logger.setLevel('ERROR')

import shutil
import pathlib
import pickle
import itertools

import pandas as pd
import numpy as np
import joblib

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler, MinMaxScaler, FunctionTransformer

# from sklearn.model_selection import GridSearchCV
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    roc_curve,
    roc_auc_score,
    precision_recall_curve,
    precision_score,
    recall_score,
    average_precision_score
)
# from sklearn import linear_model

from tensorflow.keras import models, layers

# from feature_utils import CategoricalEncoder, DataFrameSelector

from pp_pipeline_utils import (
    splitx,
    DataFrameSelector,
    CategoricalEncoder
)

from metric_utils import (
    plot_precision_recall,
    plot_roc,
    plot_precision_vs_score,
    precision_at_score_percentile,
    precision_by_score_buckets,
    plot_precision_by_score_buckets,
    plot_bucket_counts
)

# from score2ppv import score2ppv, score2ppv_model

# %%
np.random.seed(42)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_palette(sns.color_palette("Set2", 10))

# %%
features_file = 'data/cig_features.parq'

# %%
features = pd.read_parquet(features_file)

# %%
features.sample(5).T
# Out:
#                                                                        4522  \
# lead_id                                                             9055365
# form_data_id                                                         438970
# lead_match_client_id                                                   5815
# structured_campaign_name  Martin Resource Management : Regional (Martin ...
# company_nicename                                 Martin Resource Management
# full_name                                                       Curtis Hale
# hired                                                                     0
# city                                                               Longview
# state                                                                    TX
# zip                                                                   75604
# years_otr_exp                                                   11-15 years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    1
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                1
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   0
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   1
# van                                                                       1
# reefer                                                                    0
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               1
# exp_yr_num                                                               13
# climate_region                                                            S
#
#                                                                        2499  \
# lead_id                                                             9337921
# form_data_id                                                         454948
# lead_match_client_id                                                   5709
# structured_campaign_name  Trans System Inc : System Transport Pacific No...
# company_nicename                                           System Transport
# full_name                                                      Danny Malone
# hired                                                                     0
# city                                                             Long Beach
# state                                                                    CA
# zip                                                                   90804
# years_otr_exp                                                  18-24 months
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                0
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   1
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                                2
# climate_region                                                            W
#
#                                                                       1413  \
# lead_id                                                            1660939
# form_data_id                                                        230119
# lead_match_client_id                                                    10
# structured_campaign_name  US Xpress : Dedicated : p5 : a13 : M_1140093 (R)
# company_nicename                                                 US Xpress
# full_name                                                    Louis Hubbard
# hired                                                                    1
# city                                                            Montgomery
# state                                                                   AL
# zip                                                                  36106
# years_otr_exp                                                   0-3 months
# lease_purchase                                                           0
# drivers_license_class_a                                                  1
# driver_type                                                        student
# hazmat                                                                   0
# tanker                                                                   0
# doublestriples                                                           0
# tickets                                                                  0
# job_alerts                                                               1
# sms_alerts_opt_in                                                        0
# came_from_suggested_job                                                  0
# run_single                                                               0
# run_team                                                                 0
# flatbed                                                                  0
# van                                                                      0
# reefer                                                                   0
# specialized                                                              0
# multi                                                                    0
# oversized                                                                0
# stepdeck                                                                 0
# heavy_haul                                                               0
# haul_tanker                                                              0
# exp_yr_num                                                            0.25
# climate_region                                                          SE
#
#                                                                        4357  \
# lead_id                                                            13010742
# form_data_id                                                        1134721
# lead_match_client_id                                                     11
# structured_campaign_name  K and B Transportation Inc. : otr (OTR 4) : PM...
# company_nicename                                         K&B Transportation
# full_name                                                      ROBERT TOBAR
# hired                                                                     1
# city                                                              Covington
# state                                                                    TN
# zip                                                                   38019
# years_otr_exp                                                  18-24 months
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                1
# sms_alerts_opt_in                                                         0
# came_from_suggested_job                                                   1
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    0
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                                2
# climate_region                                                            C
#
#                                                                        3830
# lead_id                                                            10484415
# form_data_id                                                         672895
# lead_match_client_id                                                   5817
# structured_campaign_name  Ozark : Company Driver : PMC p5 : a1 : M_11350...
# company_nicename                                     Ozark Motor Lines, Inc
# full_name                                                       Joel Bishop
# hired                                                                     1
# city                                                              Flat Rock
# state                                                                    NC
# zip                                                                   28731
# years_otr_exp                                                       5 years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                0
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   0
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   1
# van                                                                       1
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                                5
# climate_region                                                           SE

# %%
features.hired.sum()
# Out:
# 1558

# %%
p_hired = features.hired.sum() / len(features)
p_hired
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad11b411a24a> in <module>
# ----> 1 p_hired = features.hired.sum() / len(features)
#
# NameError: name 'features' is not defined

# %%
def ordinal_keys(s):
    sset = set(s)
    sset.add('')
    return sorted(sset)

# %%
category_keys = [
    'driver_type',
    'climate_region'
]

for ck in category_keys:
    features[ck] = features[ck].fillna('')

category_values = {x: ordinal_keys(features[x].unique()) for x in category_keys}
category_lookup = {x:x for x in category_keys}

def get_cat_vals(cat):
    return category_values[category_lookup[cat]]

def make_cat_encoder(atts, encoding='onehot', handle_unknown='ignore'):
    return CategoricalEncoder(encoding=encoding,
                              categories=[get_cat_vals(x) for x in atts],
                              handle_unknown=handle_unknown)

# %%
numeric_atts = [
    'exp_yr_num',
    'tickets',
    # rest are boolean
    
    'lease_purchase',
    'drivers_license_class_a',
    'hazmat',
    'tanker',
    'doublestriples',
    'job_alerts',
    'sms_alerts_opt_in',
    'came_from_suggested_job',
    'run_single',
    'run_team',
    'flatbed',
    'van',
    'reefer',
    'multi',
    'oversized',
    'stepdeck',
    'heavy_haul',
    'haul_tanker',
]

category_atts = [
    'driver_type',
    'climate_region'
]

# %%
train_set, test_set = train_test_split(features.copy(), test_size=0.2)
len(train_set), len(test_set)
# Out:
# (4090, 1023)

# %%
num_pipeline = Pipeline([
    ('num_selector', DataFrameSelector(numeric_atts)),
    ('std_scaler', StandardScaler())
])

cat_pipeline = Pipeline([
    ('cat_selector', DataFrameSelector(category_atts)),
    ('onehot_encoder', make_cat_encoder(category_atts, encoding='onehot', handle_unknown='error'))
])

pipeline = FeatureUnion([
    ('num_pipeline', num_pipeline),
    ('cat_pipeline', cat_pipeline)
])

# %%
# %%time
pipeline.fit(train_set)
# Out:
# CPU times: user 7.77 ms, sys: 0 ns, total: 7.77 ms
# Wall time: 7.29 ms
# FeatureUnion(n_jobs=None,
#              transformer_list=[('num_pipeline',
#                                 Pipeline(memory=None,
#                                          steps=[('num_selector',
#                                                  DataFrameSelector(attribute_names=['exp_yr_num',
#                                                                                     'tickets',
#                                                                                     'lease_purchase',
#                                                                                     'drivers_license_class_a',
#                                                                                     'hazmat',
#                                                                                     'tanker',
#                                                                                     'doublestriples',
#                                                                                     'job_alerts',
#                                                                                     'sms_alerts_opt_in',
#                                                                                     'came_from_suggested_job',
#                                                                                     'run_single',
#                                                                                     'run_team',
#                                                                                     'flatbed',
#                                                                                     'van',
#                                                                                     'reefer',
#                                                                                     'mu...
#                                                  DataFrameSelector(attribute_names=['driver_type',
#                                                                                     'climate_region'])),
#                                                 ('onehot_encoder',
#                                                  CategoricalEncoder(categories=[['',
#                                                                                  'company_driver',
#                                                                                  'lease_purchase',
#                                                                                  'owner_operator',
#                                                                                  'student'],
#                                                                                 ['',
#                                                                                  'AK',
#                                                                                  'C',
#                                                                                  'ENC',
#                                                                                  'HI',
#                                                                                  'NE',
#                                                                                  'NW',
#                                                                                  'S',
#                                                                                  'SE',
#                                                                                  'SW',
#                                                                                  'W',
#                                                                                  'WNC']],
#                                                                     dtype=<class 'numpy.float64'>,
#                                                                     encoding='onehot',
#                                                                     handle_unknown='error'))],
#                                          verbose=False))],
#              transformer_weights=None, verbose=False)

# %%
X_train = pipeline.transform(train_set).toarray()
y_train = train_set.hired

# %%
X_test = pipeline.transform(test_set).toarray()
y_test = test_set.hired

# %%
X_train.shape, X_test.shape
# Out:
# ((4090, 37), (1023, 37))

# %%
n_features = X_train.shape[1]
n_features
# Out:
# 37

# %%
input = layers.Input(shape=(n_features,))
output = layers.Dense(1, activation='sigmoid')(input)

model = models.Model(input, output)
model.compile(optimizer='rmsprop', loss='binary_crossentropy')

# %%
# %%time
history = model.fit(X_train, y_train, batch_size=1024, epochs=200,
          class_weight=compute_class_weight('balanced', [0,1], y_train)
         )
# Out:
# Epoch 1/200
# 4090/4090 [==============================] - 1s 165us/sample - loss: 0.8887
# Epoch 2/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.8745
# Epoch 3/200
# 4090/4090 [==============================] - 0s 3us/sample - loss: 0.8644
# Epoch 4/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.8557
# Epoch 5/200
# 4090/4090 [==============================] - 0s 3us/sample - loss: 0.8476
# Epoch 6/200
# 4090/4090 [==============================] - 0s 3us/sample - loss: 0.8400
# Epoch 7/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.8327
# Epoch 8/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.8256
# Epoch 9/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.8187
# Epoch 10/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.8119
# Epoch 11/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.8053
# Epoch 12/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7988
# Epoch 13/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7924
# Epoch 14/200
# 4090/4090 [==============================] - 0s 3us/sample - loss: 0.7861
# Epoch 15/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7798
# Epoch 16/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7737
# Epoch 17/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7677
# Epoch 18/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7618
# Epoch 19/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7560
# Epoch 20/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7503
# Epoch 21/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7446
# Epoch 22/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7390
# Epoch 23/200
# 4090/4090 [==============================] - ETA: 0s - loss: 0.741 - 0s 2us/sample - loss: 0.7335
# Epoch 24/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7281
# Epoch 25/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7228
# Epoch 26/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7176
# Epoch 27/200
# 4090/4090 [==============================] - 0s 3us/sample - loss: 0.7125
# Epoch 28/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7074
# Epoch 29/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.7024
# Epoch 30/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6975
# Epoch 31/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6927
# Epoch 32/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6880
# Epoch 33/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6834
# Epoch 34/200
# 4090/4090 [==============================] - 0s 3us/sample - loss: 0.6788
# Epoch 35/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6744
# Epoch 36/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6700
# Epoch 37/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6658
# Epoch 38/200
# 4090/4090 [==============================] - 0s 3us/sample - loss: 0.6616
# Epoch 39/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6575
# Epoch 40/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6534
# Epoch 41/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6494
# Epoch 42/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6455
# Epoch 43/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6417
# Epoch 44/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6380
# Epoch 45/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6343
# Epoch 46/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6307
# Epoch 47/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6272
# Epoch 48/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6237
# Epoch 49/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6204
# Epoch 50/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6171
# Epoch 51/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6138
# Epoch 52/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6107
# Epoch 53/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6076
# Epoch 54/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6045
# Epoch 55/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.6016
# Epoch 56/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5987
# Epoch 57/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5958
# Epoch 58/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5930
# Epoch 59/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5902
# Epoch 60/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5876
# Epoch 61/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5849
# Epoch 62/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5824
# Epoch 63/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5799
# Epoch 64/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5774
# Epoch 65/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5750
# Epoch 66/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5727
# Epoch 67/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5704
# Epoch 68/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5682
# Epoch 69/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5660
# Epoch 70/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5639
# Epoch 71/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5618
# Epoch 72/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5598
# Epoch 73/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5578
# Epoch 74/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5559
# Epoch 75/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5540
# Epoch 76/200
# 4090/4090 [==============================] - 0s 3us/sample - loss: 0.5522
# Epoch 77/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5504
# Epoch 78/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5486
# Epoch 79/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5469
# Epoch 80/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5452
# Epoch 81/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5436
# Epoch 82/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5421
# Epoch 83/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5405
# Epoch 84/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5390
# Epoch 85/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5376
# Epoch 86/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5362
# Epoch 87/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5348
# Epoch 88/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5335
# Epoch 89/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5321
# Epoch 90/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5309
# Epoch 91/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5296
# Epoch 92/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5284
# Epoch 93/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5273
# Epoch 94/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5261
# Epoch 95/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5250
# Epoch 96/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5240
# Epoch 97/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5229
# Epoch 98/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5219
# Epoch 99/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5209
# Epoch 100/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5199
# Epoch 101/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5190
# Epoch 102/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5181
# Epoch 103/200
# 4090/4090 [==============================] - ETA: 0s - loss: 0.517 - 0s 2us/sample - loss: 0.5172
# Epoch 104/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5164
# Epoch 105/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5156
# Epoch 106/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5148
# Epoch 107/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5141
# Epoch 108/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5133
# Epoch 109/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5126
# Epoch 110/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5119
# Epoch 111/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5113
# Epoch 112/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5107
# Epoch 113/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5100
# Epoch 114/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5094
# Epoch 115/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5089
# Epoch 116/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5083
# Epoch 117/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5077
# Epoch 118/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5072
# Epoch 119/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5067
# Epoch 120/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5062
# Epoch 121/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5058
# Epoch 122/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5053
# Epoch 123/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5049
# Epoch 124/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5045
# Epoch 125/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5041
# Epoch 126/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5037
# Epoch 127/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5033
# Epoch 128/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5030
# Epoch 129/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5026
# Epoch 130/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5023
# Epoch 131/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5020
# Epoch 132/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5017
# Epoch 133/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5014
# Epoch 134/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5011
# Epoch 135/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5008
# Epoch 136/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5005
# Epoch 137/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5003
# Epoch 138/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.5000
# Epoch 139/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4997
# Epoch 140/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4995
# Epoch 141/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4992
# Epoch 142/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4990
# Epoch 143/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4988
# Epoch 144/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4986
# Epoch 145/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4983
# Epoch 146/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4981
# Epoch 147/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4980
# Epoch 148/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4978
# Epoch 149/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4975
# Epoch 150/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4973
# Epoch 151/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4971
# Epoch 152/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4970
# Epoch 153/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4968
# Epoch 154/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4966
# Epoch 155/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4964
# Epoch 156/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4963
# Epoch 157/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4961
# Epoch 158/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4959
# Epoch 159/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4958
# Epoch 160/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4956
# Epoch 161/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4955
# Epoch 162/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4953
# Epoch 163/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4952
# Epoch 164/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4950
# Epoch 165/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4949
# Epoch 166/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4947
# Epoch 167/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4946
# Epoch 168/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4945
# Epoch 169/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4944
# Epoch 170/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4942
# Epoch 171/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4941
# Epoch 172/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4940
# Epoch 173/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4938
# Epoch 174/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4937
# Epoch 175/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4936
# Epoch 176/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4935
# Epoch 177/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4934
# Epoch 178/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4933
# Epoch 179/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4932
# Epoch 180/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4931
# Epoch 181/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4930
# Epoch 182/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4929
# Epoch 183/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4928
# Epoch 184/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4927
# Epoch 185/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4926
# Epoch 186/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4925
# Epoch 187/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4924
# Epoch 188/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4923
# Epoch 189/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4923
# Epoch 190/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4922
# Epoch 191/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4921
# Epoch 192/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4920
# Epoch 193/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4920
# Epoch 194/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4919
# Epoch 195/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4918
# Epoch 196/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4917
# Epoch 197/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4917
# Epoch 198/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4916
# Epoch 199/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4915
# Epoch 200/200
# 4090/4090 [==============================] - 0s 2us/sample - loss: 0.4915
# CPU times: user 2.95 s, sys: 508 ms, total: 3.45 s
# Wall time: 2.46 s

# %%
y_score = model.predict(X_test)

# %%
roc_auc_score(y_test, y_score)
# Out:
# 0.818245338814959

# %%
average_precision_score(y_test, y_score)
# Out:
# 0.6735499561085342

# %%
precision_at_score_percentile(y_test, y_score, 80)
# Out:
# 0.7560975609756098

# %%
precision_at_score_percentile(y_test, y_score, 90)
# Out:
# 0.7864077669902912

# %%
precision_at_score_percentile(y_test, y_score, 99)
# Out:
# 0.7272727272727273

# %%
plot_roc(y_test, y_score)

# %%
plot_precision_recall(y_test, y_score)

# %%
plt.figure(figsize=(24,8))
plot_bucket_counts(y_test, y_score, 10)

# %%
# len(test_set)

# %%
# len(y_score)

# %%
# y_score

# %%
# test_set['score'] = y_score

# %%
# test_set.sample(5).T

# %%
# test_set.to_excel('data/cig_test_scored.xlsx', index=False)
