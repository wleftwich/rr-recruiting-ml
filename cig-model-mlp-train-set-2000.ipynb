# %% [markdown]
# # Careers in gear
# ## Predict hire / nohire from lead_details.csv
#
# ### MLP model with embedded category vectors
#
# ## Limit train set to 2000

# %%
import logging
logging.basicConfig()
logger = logging.getLogger()
logger.setLevel('ERROR')

import shutil
import pathlib
import pickle
import itertools

import pandas as pd
import numpy as np
import joblib

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler, MinMaxScaler, FunctionTransformer

# from sklearn.model_selection import GridSearchCV
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    roc_curve,
    roc_auc_score,
    precision_recall_curve,
    precision_score,
    recall_score,
    average_precision_score
)
# from sklearn import linear_model

from tensorflow.keras import models, layers

# from feature_utils import CategoricalEncoder, DataFrameSelector

from pp_pipeline_utils import (
    splitx,
    DataFrameSelector,
    CategoricalEncoder
)

from metric_utils import (
    plot_precision_recall,
    plot_roc,
    plot_precision_vs_score,
    precision_at_score_percentile,
    precision_by_score_buckets,
    plot_precision_by_score_buckets,
    plot_bucket_counts
)

# from score2ppv import score2ppv, score2ppv_model

# %%
np.random.seed(42)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_palette(sns.color_palette("Set2", 10))

# %%
features_file = 'data/cig_features.parq'

# %%
features = pd.read_parquet(features_file)

# %%
features.sample(5).T
# Out:
#                                                                        4522  \
# lead_id                                                             9055365
# form_data_id                                                         438970
# lead_match_client_id                                                   5815
# structured_campaign_name  Martin Resource Management : Regional (Martin ...
# company_nicename                                 Martin Resource Management
# full_name                                                       Curtis Hale
# hired                                                                     0
# city                                                               Longview
# state                                                                    TX
# zip                                                                   75604
# years_otr_exp                                                   11-15 years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    1
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                1
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   0
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   1
# van                                                                       1
# reefer                                                                    0
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               1
# exp_yr_num                                                               13
# climate_region                                                            S
#
#                                                                        2499  \
# lead_id                                                             9337921
# form_data_id                                                         454948
# lead_match_client_id                                                   5709
# structured_campaign_name  Trans System Inc : System Transport Pacific No...
# company_nicename                                           System Transport
# full_name                                                      Danny Malone
# hired                                                                     0
# city                                                             Long Beach
# state                                                                    CA
# zip                                                                   90804
# years_otr_exp                                                  18-24 months
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                0
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   1
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                                2
# climate_region                                                            W
#
#                                                                       1413  \
# lead_id                                                            1660939
# form_data_id                                                        230119
# lead_match_client_id                                                    10
# structured_campaign_name  US Xpress : Dedicated : p5 : a13 : M_1140093 (R)
# company_nicename                                                 US Xpress
# full_name                                                    Louis Hubbard
# hired                                                                    1
# city                                                            Montgomery
# state                                                                   AL
# zip                                                                  36106
# years_otr_exp                                                   0-3 months
# lease_purchase                                                           0
# drivers_license_class_a                                                  1
# driver_type                                                        student
# hazmat                                                                   0
# tanker                                                                   0
# doublestriples                                                           0
# tickets                                                                  0
# job_alerts                                                               1
# sms_alerts_opt_in                                                        0
# came_from_suggested_job                                                  0
# run_single                                                               0
# run_team                                                                 0
# flatbed                                                                  0
# van                                                                      0
# reefer                                                                   0
# specialized                                                              0
# multi                                                                    0
# oversized                                                                0
# stepdeck                                                                 0
# heavy_haul                                                               0
# haul_tanker                                                              0
# exp_yr_num                                                            0.25
# climate_region                                                          SE
#
#                                                                        4357  \
# lead_id                                                            13010742
# form_data_id                                                        1134721
# lead_match_client_id                                                     11
# structured_campaign_name  K and B Transportation Inc. : otr (OTR 4) : PM...
# company_nicename                                         K&B Transportation
# full_name                                                      ROBERT TOBAR
# hired                                                                     1
# city                                                              Covington
# state                                                                    TN
# zip                                                                   38019
# years_otr_exp                                                  18-24 months
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                1
# sms_alerts_opt_in                                                         0
# came_from_suggested_job                                                   1
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    0
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                                2
# climate_region                                                            C
#
#                                                                        3830
# lead_id                                                            10484415
# form_data_id                                                         672895
# lead_match_client_id                                                   5817
# structured_campaign_name  Ozark : Company Driver : PMC p5 : a1 : M_11350...
# company_nicename                                     Ozark Motor Lines, Inc
# full_name                                                       Joel Bishop
# hired                                                                     1
# city                                                              Flat Rock
# state                                                                    NC
# zip                                                                   28731
# years_otr_exp                                                       5 years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                0
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   0
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   1
# van                                                                       1
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                                5
# climate_region                                                           SE

# %%
features.hired.sum()
# Out:
# 1558

# %%
features.hired.sum() / len(features)
# Out:
# 0.30471347545472327

# %%
def ordinal_keys(s):
    sset = set(s)
    sset.add('')
    return sorted(sset)

# %%
category_keys = [
    'driver_type',
    'climate_region'
]

for ck in category_keys:
    features[ck] = features[ck].fillna('')

category_values = {x: ordinal_keys(features[x].unique()) for x in category_keys}
category_lookup = {x:x for x in category_keys}

def get_cat_vals(cat):
    return category_values[category_lookup[cat]]

def make_cat_encoder(atts, encoding='onehot', handle_unknown='ignore'):
    return CategoricalEncoder(encoding=encoding,
                              categories=[get_cat_vals(x) for x in atts],
                              handle_unknown=handle_unknown)

# %%
numeric_atts = [
    'exp_yr_num',
    'tickets',
    # rest are boolean
    
    'lease_purchase',
    'drivers_license_class_a',
    'hazmat',
    'tanker',
    'doublestriples',
    'job_alerts',
    'sms_alerts_opt_in',
    'came_from_suggested_job',
    'run_single',
    'run_team',
    'flatbed',
    'van',
    'reefer',
    'multi',
    'oversized',
    'stepdeck',
    'heavy_haul',
    'haul_tanker',
]

category_atts = [
    'driver_type',
    'climate_region'
]

# %%
train_set, test_set = train_test_split(features.copy(), test_size=0.2)
len(train_set), len(test_set)
# Out:
# (4090, 1023)

# %%
train_set = train_set.sample(2000)

# %%
splitx_ft = FunctionTransformer(splitx, validate=True, kw_args={'numlen': len(numeric_atts)})

# %%
num_pipeline = Pipeline([
    ('num_selector', DataFrameSelector(numeric_atts)),
    ('std_scaler', StandardScaler())
])

cat_pipeline = Pipeline([
    ('cat_selector', DataFrameSelector(category_atts)),
    ('ordinal_encoder', make_cat_encoder(category_atts, encoding='ordinal', handle_unknown='error'))
])

fu_pipeline = FeatureUnion([
    ('num_pipeline', num_pipeline),
    ('cat_pipeline', cat_pipeline)
])

pipeline = Pipeline([
    ('fu_pipeline', fu_pipeline),
    ('splitx_ft', splitx_ft)
])

# %%
# %%time
pipeline.fit(train_set)
# Out:
# CPU times: user 10.1 ms, sys: 440 µs, total: 10.6 ms
# Wall time: 8.94 ms
# Pipeline(memory=None,
#          steps=[('fu_pipeline',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('num_pipeline',
#                                                  Pipeline(memory=None,
#                                                           steps=[('num_selector',
#                                                                   DataFrameSelector(attribute_names=['exp_yr_num',
#                                                                                                      'tickets',
#                                                                                                      'lease_purchase',
#                                                                                                      'drivers_license_class_a',
#                                                                                                      'hazmat',
#                                                                                                      'tanker',
#                                                                                                      'doublestriples',
#                                                                                                      'job_alerts',
#                                                                                                      'sms_alerts_opt_in',
#                                                                                                      'came_from_suggested_job',
#                                                                                                      'run_sing...
#                                                                                      dtype=<class 'numpy.float64'>,
#                                                                                      encoding='ordinal',
#                                                                                      handle_unknown='error'))],
#                                                           verbose=False))],
#                               transformer_weights=None, verbose=False)),
#                 ('splitx_ft',
#                  FunctionTransformer(accept_sparse=False, check_inverse=True,
#                                      func=<function splitx at 0x7fc4ee8571e0>,
#                                      inv_kw_args=None, inverse_func=None,
#                                      kw_args={'numlen': 20},
#                                      pass_y='deprecated', validate=True))],
#          verbose=False)

# %%
X_train = pipeline.transform(train_set)
y_train = train_set.hired

# %%
X_test = pipeline.transform(test_set)
y_test = test_set.hired

# %%
inputs = []
base_layers = []
embedclasses = {}

numeric_count = len(numeric_atts)
inp = layers.Input(shape=(numeric_count,))
inputs.append(inp)
numeric_layer = layers.Dense(numeric_count, name='numeric_input')(inp)
base_layers.append(numeric_layer)

for catname in category_atts:
    m = len(get_cat_vals(catname))
    n = min((m + 1) // 2, 50)
    embedname = category_lookup[catname]
    if embedname in embedclasses:
        embedclass = embedclasses[embedname]
    else:
        embedclass = layers.Embedding(m, n, input_length=1, name=(embedname + '_embedding'))
        embedclasses[embedname] = embedclass
    inp = layers.Input(shape=(1,))
    inputs.append(inp)
    emb = embedclass(inp)
    emb_reshaped = layers.Reshape(target_shape=(n,))(emb)
    base_layers.append(emb_reshaped)

# %%
len(X_train)
# Out:
# 3

# %%
[x.shape for x in X_train]
# Out:
# [(2000, 20), (2000,), (2000,)]

# %%
x = layers.Concatenate()(base_layers)
x = layers.Dense(16, activation='relu')(x)
x = layers.Dropout(0.2)(x)
output = layers.Dense(1, activation='sigmoid')(x)

model = models.Model(inputs, output)
model.compile(optimizer='rmsprop', loss='binary_crossentropy')

# %%
# %%time
history = model.fit(X_train, y_train, batch_size=1024, epochs=40,
          class_weight=compute_class_weight('balanced', [0,1], y_train)
         )
# Out:
# Epoch 1/40
# 2000/2000 [==============================] - 2s 828us/sample - loss: 0.6543
# Epoch 2/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.6419
# Epoch 3/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.6359
# Epoch 4/40
# 2000/2000 [==============================] - 0s 5us/sample - loss: 0.6285
# Epoch 5/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.6164
# Epoch 6/40
# 2000/2000 [==============================] - 0s 3us/sample - loss: 0.6098
# Epoch 7/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.6035
# Epoch 8/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.6006
# Epoch 9/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5983
# Epoch 10/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5872
# Epoch 11/40
# 2000/2000 [==============================] - 0s 3us/sample - loss: 0.5783
# Epoch 12/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5807
# Epoch 13/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5868
# Epoch 14/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5761
# Epoch 15/40
# 2000/2000 [==============================] - 0s 3us/sample - loss: 0.5713
# Epoch 16/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5734
# Epoch 17/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5717
# Epoch 18/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5645
# Epoch 19/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5677
# Epoch 20/40
# 2000/2000 [==============================] - 0s 3us/sample - loss: 0.5515
# Epoch 21/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5559
# Epoch 22/40
# 2000/2000 [==============================] - 0s 3us/sample - loss: 0.5512
# Epoch 23/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5549
# Epoch 24/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5487
# Epoch 25/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5452
# Epoch 26/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5424
# Epoch 27/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5350
# Epoch 28/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5401
# Epoch 29/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5413
# Epoch 30/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5348
# Epoch 31/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5373
# Epoch 32/40
# 2000/2000 [==============================] - 0s 3us/sample - loss: 0.5374
# Epoch 33/40
# 2000/2000 [==============================] - 0s 5us/sample - loss: 0.5353
# Epoch 34/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5412
# Epoch 35/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5242
# Epoch 36/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5249
# Epoch 37/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5203
# Epoch 38/40
# 2000/2000 [==============================] - 0s 3us/sample - loss: 0.5307
# Epoch 39/40
# 2000/2000 [==============================] - 0s 5us/sample - loss: 0.5210
# Epoch 40/40
# 2000/2000 [==============================] - 0s 4us/sample - loss: 0.5241
# CPU times: user 1.24 s, sys: 440 ms, total: 1.68 s
# Wall time: 2.2 s

# %%
y_score = model.predict(X_test)

# %%
roc_auc_score(y_test, y_score)
# Out:
# 0.767445634534242

# %%
average_precision_score(y_test, y_score)
# Out:
# 0.650073185828866

# %%
precision_at_score_percentile(y_test, y_score, 80)
# Out:
# 0.7073170731707317

# %%
precision_at_score_percentile(y_test, y_score, 90)
# Out:
# 0.8446601941747572

# %%
precision_at_score_percentile(y_test, y_score, 99)
# Out:
# 0.8181818181818182

# %%
plot_roc(y_test, y_score)

# %%
plot_precision_recall(y_test, y_score)

# %%
plt.figure(figsize=(24,8))
plot_bucket_counts(y_test, y_score, 10)

# %%
len(test_set)
# Out:
# 1023

# %%
len(y_score)
# Out:
# 1023

# %%
y_score
# Out:
# array([[0.19286874],
#        [0.13493067],
#        [0.520492  ],
#        ...,
#        [0.0736484 ],
#        [0.6438723 ],
#        [0.3389106 ]], dtype=float32)

# %%
test_set['score'] = y_score

# %%
test_set.sample(5).T
# Out:
#                                                                        3620  \
# lead_id                                                             8966728
# form_data_id                                                         433333
# lead_match_client_id                                                   5575
# structured_campaign_name  Crete Carrier Corporation : National : PMC p5 ...
# company_nicename                                  Crete Carrier Corporation
# full_name                                                   Peter Gallagher
# hired                                                                     0
# city                                                         Virginia Beach
# state                                                                    VA
# zip                                                                   23456
# years_otr_exp                                                     30+ years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    1
# doublestriples                                                            0
# tickets                                                                   1
# job_alerts                                                                1
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   1
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               1
# exp_yr_num                                                               30
# climate_region                                                           SE
# score                                                              0.175086
#
#                                     2109  \
# lead_id                          1118791
# form_data_id                       79624
# lead_match_client_id                5567
# structured_campaign_name            None
# company_nicename           Werner - West
# full_name                  David Robbins
# hired                                  1
# city                         Porterville
# state                                 CA
# zip                                93257
# years_otr_exp                 0-3 months
# lease_purchase                         0
# drivers_license_class_a                1
# driver_type               company_driver
# hazmat                                 0
# tanker                                 0
# doublestriples                         0
# tickets                                1
# job_alerts                             0
# sms_alerts_opt_in                      0
# came_from_suggested_job                0
# run_single                             0
# run_team                               0
# flatbed                                0
# van                                    0
# reefer                                 0
# specialized                            0
# multi                                  0
# oversized                              0
# stepdeck                               0
# heavy_haul                             0
# haul_tanker                            0
# exp_yr_num                          0.25
# climate_region                         W
# score                           0.785518
#
#                                                                        4820  \
# lead_id                                                             9663077
# form_data_id                                                         478202
# lead_match_client_id                                                     39
# structured_campaign_name  Koch Trucking : PMC : PMC p5 : a3 : M_1138207 (R)
# company_nicename                                              Koch Trucking
# full_name                                                         Ted Lewis
# hired                                                                     1
# city                                                             Blackshear
# state                                                                    GA
# zip                                                                   31516
# years_otr_exp                                                   21-25 years
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                1
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   0
# run_single                                                                1
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       1
# reefer                                                                    1
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                               23
# climate_region                                                           SE
# score                                                              0.364906
#
#                                                                       4410  \
# lead_id                                                            1715522
# form_data_id                                                        244528
# lead_match_client_id                                                    10
# structured_campaign_name  US Xpress : Dedicated : p5 : a13 : M_1140093 (R)
# company_nicename                                                 US Xpress
# full_name                                                    Herbert Woods
# hired                                                                    1
# city                                                               Jackson
# state                                                                   TN
# zip                                                                  38301
# years_otr_exp                                                       1 year
# lease_purchase                                                           0
# drivers_license_class_a                                                  1
# driver_type                                                 company_driver
# hazmat                                                                   0
# tanker                                                                   0
# doublestriples                                                           0
# tickets                                                                  2
# job_alerts                                                               0
# sms_alerts_opt_in                                                        0
# came_from_suggested_job                                                  0
# run_single                                                               0
# run_team                                                                 0
# flatbed                                                                  0
# van                                                                      0
# reefer                                                                   0
# specialized                                                              0
# multi                                                                    0
# oversized                                                                0
# stepdeck                                                                 0
# heavy_haul                                                               0
# haul_tanker                                                              0
# exp_yr_num                                                               1
# climate_region                                                           C
# score                                                             0.772522
#
#                                                                        1558
# lead_id                                                             1570550
# form_data_id                                                         210048
# lead_match_client_id                                                      3
# structured_campaign_name  Marten Transport Ltd. : PMC Main : PMC p5 : a6...
# company_nicename                                           Marten Transport
# full_name                                                      Albert Taala
# hired                                                                     1
# city                                                         Airway Heights
# state                                                                    WA
# zip                                                                   99001
# years_otr_exp                                                   9-12 months
# lease_purchase                                                            0
# drivers_license_class_a                                                   1
# driver_type                                                  company_driver
# hazmat                                                                    0
# tanker                                                                    0
# doublestriples                                                            0
# tickets                                                                   0
# job_alerts                                                                1
# sms_alerts_opt_in                                                         1
# came_from_suggested_job                                                   1
# run_single                                                                0
# run_team                                                                  0
# flatbed                                                                   0
# van                                                                       0
# reefer                                                                    0
# specialized                                                               0
# multi                                                                     0
# oversized                                                                 0
# stepdeck                                                                  0
# heavy_haul                                                                0
# haul_tanker                                                               0
# exp_yr_num                                                                1
# climate_region                                                           NW
# score                                                              0.468742

# %%
test_set.to_excel('data/cig_test_scored.xlsx', index=False)
